# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data1.csv")

# %%
data
# Out:
#      Areas  Rents
# 0      600  16000
# 1     1500  37000
# 2      552  20000
# 3     1500  28000
# 4     3150  85000
# ..     ...    ...
# 975   1700  65000
# 976    350      0
# 977   1300  25000
# 978   1030  27000
# 979    500  25000
#
# [980 rows x 2 columns]

# %%
plt.scatter(data['Areas'] , data['Rents'] , label = 'Data' , color = 'blue' , marker = 'o')
plt.xlabel('Areas')
plt.ylabel('Rents')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3).fit(data[['Areas' , 'Rents']])

# %%
plt.scatter(data['Areas'] , data['Rents'] , c = kmeans.labels_.astype(float), alpha=0.5)
plt.xlabel('Areas')
plt.ylabel('Rents')
x_left , x_right = plt.xlim()
y_left , y_right = plt.ylim()
plt.show()

# %%
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[ 1104.42087542, 24920.87542088],
#        [  633.27272727,  9495.47021944],
#        [ 1972.84444444, 59755.55555556]])

# %%
plt.scatter(centroids[: , 0] , centroids[: , 1] , c = 'r')
plt.xlabel('Areas')
plt.ylabel('Rents')
plt.xlim(x_left , x_right)
plt.ylim(y_left , y_right)
plt.show()

# %%
plt.scatter(data['Areas'] , data['Rents'] , c = kmeans.labels_.astype(float), alpha=0.5)
plt.scatter(centroids[: , 0] , centroids[: , 1] , c = 'r' , label = 'Centroids')
plt.xlabel('Areas')
plt.ylabel('Rents')
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.scatter(data['Areas'] , data['Rents'] , c = kmeans.labels_.astype(float), alpha=0.5)
plt.scatter(centroids[: , 0] , centroids[: , 1] , c = 'r' , label = 'Centroids')
plt.xlabel('Areas')
plt.ylabel('Rents')
plt.legend(loc = 'upper right')
plt.xlim(0 , 2000)
plt.ylim(0 , 40000)
plt.show()

# %%
plt.scatter(data['Areas'] , data['Rents'] , c = kmeans.labels_.astype(float), alpha=0.5)
plt.scatter(centroids[: , 0] , centroids[: , 1] , c = 'r' , label = 'Centroids')
plt.xlabel('Areas')
plt.ylabel('Rents')
plt.legend(loc = 'upper right')
plt.xlim(1000 , 5500)
plt.ylim(43000 , 100000)
plt.show()
